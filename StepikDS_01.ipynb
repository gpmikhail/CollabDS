# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

studentsPerformance = pd.read_csv('https://stepik.org/media/attachments/course/4852/StudentsPerformance.csv')
print (studentsPerformance)
print('kekpperkl')
# Out:
#      gender race/ethnicity  ... reading score writing score
# 0    female        group B  ...            72            74
# 1    female        group C  ...            90            88
# 2    female        group B  ...            95            93
# 3      male        group A  ...            57            44
# 4      male        group C  ...            78            75
# ..      ...            ...  ...           ...           ...
# 995  female        group E  ...            99            95
# 996    male        group C  ...            55            55
# 997  female        group C  ...            71            65
# 998  female        group D  ...            78            77
# 999  female        group D  ...            86            86
#
# [1000 rows x 8 columns]
# kekpperkl

# %%
ls
# Out:
# sample_data/

# %%
mkdir 1

# %%
ls
# Out:
# 1/  sample_data/

# %%
studentsPerformance.iloc[0:5, 0:3]
# Out:
#    gender race/ethnicity parental level of education
# 0  female        group B           bachelor's degree
# 1  female        group C                some college
# 2  female        group B             master's degree
# 3    male        group A          associate's degree
# 4    male        group C                some college

# %%
studentsPerformance_with_names = studentsPerformance.iloc[[0,3,4,7,8]]

# %%
studentsPerformance_with_names.index = ["A", "b", "3", "NAME", "INDX"]

# %%
print (studentsPerformance_with_names)
# Out:
#       gender race/ethnicity  ... reading score writing score
# A     female        group B  ...            72            74
# b       male        group A  ...            57            44
# 3       male        group C  ...            78            75
# NAME    male        group B  ...            43            39
# INDX    male        group D  ...            64            67
#
# [5 rows x 8 columns]

# %%
studentsPerformance_with_names.iloc[:]
# Out:
#       gender race/ethnicity  ... reading score writing score
# A     female        group B  ...            72            74
# b       male        group A  ...            57            44
# 3       male        group C  ...            78            75
# NAME    male        group B  ...            43            39
# INDX    male        group D  ...            64            67
#
# [5 rows x 8 columns]

# %%
pd.set_option('display.max_columns', 0)

# %%
studentsPerformance_with_names.iloc[:, 0]
# Out:
# A       female
# b         male
# 3         male
# NAME      male
# INDX      male
# Name: gender, dtype: object

# %%
series1 = pd.Series([1,2,3], index=["a","b","c"])
series2 = pd.Series([4,5,6], index=["a","b","c"])

# %%
pd.DataFrame({'col1' : series1, 'col2' : series2})
# Out:
#    col1  col2
# a     1     4
# b     2     5
# c     3     6

# %%
studentsPerformance.shape
# Out:
# (1000, 8)

# %%
titanic = pd.read_csv('https://stepik.org/media/attachments/course/4852/titanic.csv')

# %%
titanic.shape
# Out:
# (891, 12)

# %%
titanic.dtypes.value_counts()
# Out:
# object     5
# int64      5
# float64    2
# dtype: int64

# %%
print (titanic)
# Out:
#      PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0              1         0       3  ...   7.2500   NaN         S
# 1              2         1       1  ...  71.2833   C85         C
# 2              3         1       3  ...   7.9250   NaN         S
# 3              4         1       1  ...  53.1000  C123         S
# 4              5         0       3  ...   8.0500   NaN         S
# ..           ...       ...     ...  ...      ...   ...       ...
# 886          887         0       2  ...  13.0000   NaN         S
# 887          888         1       1  ...  30.0000   B42         S
# 888          889         0       3  ...  23.4500   NaN         S
# 889          890         1       1  ...  30.0000  C148         C
# 890          891         0       3  ...   7.7500   NaN         Q
#
# [891 rows x 12 columns]

# %%
titanic.iloc[:]
# Out:
#      PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0              1         0       3  ...   7.2500   NaN         S
# 1              2         1       1  ...  71.2833   C85         C
# 2              3         1       3  ...   7.9250   NaN         S
# 3              4         1       1  ...  53.1000  C123         S
# 4              5         0       3  ...   8.0500   NaN         S
# ..           ...       ...     ...  ...      ...   ...       ...
# 886          887         0       2  ...  13.0000   NaN         S
# 887          888         1       1  ...  30.0000   B42         S
# 888          889         0       3  ...  23.4500   NaN         S
# 889          890         1       1  ...  30.0000  C148         C
# 890          891         0       3  ...   7.7500   NaN         Q
#
# [891 rows x 12 columns]

# %%
studentsPerformance.loc[studentsPerformance.gender == 'female',['gender','writing score']]
# Out:
#      gender  writing score
# 0    female             74
# 1    female             88
# 2    female             93
# 5    female             78
# 6    female             92
# ..      ...            ...
# 993  female             74
# 995  female             95
# 997  female             65
# 998  female             77
# 999  female             86
#
# [518 rows x 2 columns]

# %%
writing_score_mean = studentsPerformance['writing score'].mean()

# %%
studentsPerformance.loc[studentsPerformance['writing score'] > writing_score_mean]
# Out:
#      gender race/ethnicity  ... reading score writing score
# 0    female        group B  ...            72            74
# 1    female        group C  ...            90            88
# 2    female        group B  ...            95            93
# 4      male        group C  ...            78            75
# 5    female        group B  ...            83            78
# ..      ...            ...  ...           ...           ...
# 992  female        group D  ...            76            76
# 993  female        group D  ...            72            74
# 995  female        group E  ...            99            95
# 998  female        group D  ...            78            77
# 999  female        group D  ...            86            86
#
# [512 rows x 8 columns]

# %%
query = (studentsPerformance['writing score'] > writing_score_mean) & (studentsPerformance.gender == 'female')

# %%
print (query)
# Out:
# 0       True
# 1       True
# 2       True
# 3      False
# 4      False
#        ...
# 995     True
# 996    False
# 997    False
# 998     True
# 999     True
# Length: 1000, dtype: bool

# %%
studentsPerformance.loc[query]
# Out:
#      gender race/ethnicity  ... reading score writing score
# 0    female        group B  ...            72            74
# 1    female        group C  ...            90            88
# 2    female        group B  ...            95            93
# 5    female        group B  ...            83            78
# 6    female        group B  ...            95            92
# ..      ...            ...  ...           ...           ...
# 992  female        group D  ...            76            76
# 993  female        group D  ...            72            74
# 995  female        group E  ...            99            95
# 998  female        group D  ...            78            77
# 999  female        group D  ...            86            86
#
# [333 rows x 8 columns]

# %%
query.type
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-46-961135daee39> in <module>()
# ----> 1 query.type
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5139             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5140                 return self[name]
# -> 5141             return object.__getattribute__(self, name)
#    5142
#    5143     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'type'

# %%
query
# Out:
# 0       True
# 1       True
# 2       True
# 3      False
# 4      False
#        ...
# 995     True
# 996    False
# 997    False
# 998     True
# 999     True
# Length: 1000, dtype: bool

# %%
query.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
type(query)
# Out:
# pandas.core.series.Series

# %%
exercise_data = pd.read_csv('https://stepik.org/media/attachments/course/4852/StudentsPerformance.csv')

# %%
exercise_data
# Out:
#      gender race/ethnicity  ... reading score writing score
# 0    female        group B  ...            72            74
# 1    female        group C  ...            90            88
# 2    female        group B  ...            95            93
# 3      male        group A  ...            57            44
# 4      male        group C  ...            78            75
# ..      ...            ...  ...           ...           ...
# 995  female        group E  ...            99            95
# 996    male        group C  ...            55            55
# 997  female        group C  ...            71            65
# 998  female        group D  ...            78            77
# 999  female        group D  ...            86            86
#
# [1000 rows x 8 columns]

# %%
len(exercise_data)
# Out:
# 1000

# %%
len(exercise_data.lunch == 'free/reduced')
# Out:
# 1000

# %%
query_ex = exercise_data.lunch == 'free/reduced'

# %%
len(exercise_data[query_ex])
# Out:
# 355

# %%
len(exercise_data[query_ex]) / len(exercise_data)
# Out:
# 0.355

# %%
studData = pd.read_csv('https://stepik.org/media/attachments/course/4852/StudentsPerformance.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-769960c23489> in <module>()
# ----> 1 studData = pd.read_csv('https://stepik.org/media/attachments/course/4852/StudentsPerformance.csv')
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd

# %%
import numpy as np

# %%
exercise_data.head()
# Out:
#    gender race/ethnicity  ... reading score writing score
# 0  female        group B  ...            72            74
# 1  female        group C  ...            90            88
# 2  female        group B  ...            95            93
# 3    male        group A  ...            57            44
# 4    male        group C  ...            78            75
#
# [5 rows x 8 columns]

# %%
queryLunchStandard = (exercise_data.lunch == 'standard')
queryLunchFree = (exercise_data.lunch == 'free/reduced')

# %%
queryLunchStandard.head()
# Out:
# 0     True
# 1     True
# 2     True
# 3    False
# 4     True
# Name: lunch, dtype: bool

# %%
meanScoreStandard = exercise_data[queryLunchStandard].mean()
meanScoreFree = exercise_data[queryLunchFree].mean()

# %%
print (meanScoreStandard)
print (meanScoreFree)
# Out:
# math score       70.034109
# reading score    71.654264
# writing score    70.823256
# dtype: float64
# math score       58.921127
# reading score    64.653521
# writing score    63.022535
# dtype: float64

# %%
varScoreStandard = exercise_data[queryLunchStandard].var()
varScoreFree = exercise_data[queryLunchFree].var()

# %%
print (varScoreStandard)
print (varScoreFree)
# Out:
# math score       186.418089
# reading score    191.285560
# writing score    205.620887
# dtype: float64
# math score       229.824270
# reading score    221.871139
# writing score    238.202881
# dtype: float64

# %%
exercise_data.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
exercise_data[queryLunchStandard].describe()
# Out:
#        math score  reading score  writing score
# count  645.000000     645.000000     645.000000
# mean    70.034109      71.654264      70.823256
# std     13.653501      13.830602      14.339487
# min     19.000000      26.000000      22.000000
# 25%     61.000000      63.000000      62.000000
# 50%     69.000000      72.000000      72.000000
# 75%     80.000000      82.000000      81.000000
# max    100.000000     100.000000     100.000000

# %%
exercise_data[queryLunchFree].describe()
# Out:
#        math score  reading score  writing score
# count  355.000000     355.000000     355.000000
# mean    58.921127      64.653521      63.022535
# std     15.159956      14.895339      15.433823
# min      0.000000      17.000000      10.000000
# 25%     49.000000      56.000000      53.000000
# 50%     60.000000      65.000000      64.000000
# 75%     69.000000      75.000000      74.000000
# max    100.000000     100.000000     100.000000

# %%
exercise_data.columns = [x.replace(" ", "_") for x in exercise_data.columns]

# %%
exercise_data.head()
# Out:
#    gender race/ethnicity  ... reading_score writing_score
# 0  female        group B  ...            72            74
# 1  female        group C  ...            90            88
# 2  female        group B  ...            95            93
# 3    male        group A  ...            57            44
# 4    male        group C  ...            78            75
#
# [5 rows x 8 columns]

# %%
df_cHell = pd.read_csv('https://stepik.org/media/attachments/course/4852/column_hell.csv')

# %%
df_cHell.head()
# Out:
#       yrh&6      ohku         q  ...       tif   wuikzxt     wzuvc
# 0  0.288397  0.911359  0.488069  ...  0.081902  0.333237  0.185148
# 1  0.861276  0.134987  0.701885  ...  0.856081  0.120481  0.622113
# 2  0.775577  0.832874  0.862665  ...  0.971201  0.714558  0.702453
# 3  0.857910  0.555818  0.598305  ...  0.111621  0.373365  0.461615
# 4  0.748652  0.451725  0.252619  ...  0.428842  0.099398  0.175227
#
# [5 rows x 75 columns]

# %%
selected_columns = df_cHell.filter(like='-')

# %%
selected_columns.head
# Out:
# <bound method NDFrame.head of      umeca-4  kudbpyw-3       g-3       v-9     fla-6  hwtbyrkp-5
# 0   0.016124   0.430787  0.202407  0.725508  0.305076    0.979296
# 1   0.507115   0.671662  0.864249  0.867818  0.358859    0.160520
# 2   0.003274   0.286411  0.928865  0.719159  0.340235    0.734612
# 3   0.784139   0.863717  0.175446  0.554744  0.049325    0.621132
# 4   0.011265   0.206172  0.044151  0.163643  0.048806    0.437836
# ..       ...        ...       ...       ...       ...         ...
# 95  0.220817   0.434444  0.601738  0.146333  0.918888    0.216499
# 96  0.474131   0.176011  0.359793  0.104707  0.257690    0.066934
# 97  0.091637   0.871606  0.121075  0.907699  0.313184    0.788592
# 98  0.360106   0.172385  0.015285  0.019571  0.060751    0.403166
# 99  0.669284   0.701505  0.481430  0.024944  0.644989    0.702003
#
# [100 rows x 6 columns]>

# %%
exercise_data.groupby('gender', as_index=False) \
.agg({'math_score' : 'mean', 'reading_score' : 'mean'}) \
.rename(columns = {'math_score': 'mean_math_score', 'reading_score' : 'mean_reading_score'})
# Out:
#    gender  mean_math_score  mean_reading_score
# 0  female        63.633205           72.608108
# 1    male        68.728216           65.473029

# %%
exercise_data.groupby('lunch', as_index=False) \
.agg({'mean','var' })
# Out:
#               math_score             ... writing_score
#                      var       mean  ...           var       mean
# lunch                                ...
# free/reduced  229.824270  58.921127  ...    238.202881  63.022535
# standard      186.418089  70.034109  ...    205.620887  70.823256
#
# [2 rows x 6 columns]

# %%
exercise_data.sort_values(['gender', 'math_score'], ascending=False) \
.groupby('gender').head()
# Out:
#      gender race/ethnicity  ... reading_score writing_score
# 149    male        group E  ...           100            93
# 623    male        group A  ...            96            86
# 625    male        group D  ...            97            99
# 916    male        group E  ...           100           100
# 306    male        group E  ...            87            81
# 451  female        group E  ...            92            97
# 458  female        group E  ...           100           100
# 962  female        group E  ...           100           100
# 114  female        group E  ...           100           100
# 263  female        group E  ...            93            90
#
# [10 rows x 8 columns]

# %%
import pandas as pd
import numpy as np
dotaDf = pd.read_csv('https://stepik.org/media/attachments/course/4852/dota_hero_stats.csv')

# %%
dotaDf.head()
# Out:
#    Unnamed: 0  ...                                              roles
# 0           0  ...                       ['Carry', 'Escape', 'Nuker']
# 1           1  ...    ['Initiator', 'Durable', 'Disabler', 'Jungler']
# 2           2  ...        ['Support', 'Disabler', 'Nuker', 'Durable']
# 3           3  ...  ['Carry', 'Disabler', 'Jungler', 'Nuker', 'Ini...
# 4           4  ...        ['Support', 'Disabler', 'Nuker', 'Jungler']
#
# [5 rows x 8 columns]

# %%
dotaDf.query("legs == 8").head()
# Out:
#     Unnamed: 0 attack_type  ...  primary_attr                                   roles
# 59          59       Melee  ...           agi  ['Carry', 'Pusher', 'Escape', 'Nuker']
#
# [1 rows x 8 columns]

# %%
dotaDf.legs.count()
# Out:
# 117

# %%
dotaDf.groupby('legs', as_index=False).count()
# Out:
#    legs  Unnamed: 0  attack_type  id  localized_name  name  primary_attr  roles
# 0     0          11           11  11              11    11            11     11
# 1     2          95           95  95              95    95            95     95
# 2     4           7            7   7               7     7             7      7
# 3     6           3            3   3               3     3             3      3
# 4     8           1            1   1               1     1             1      1

# %%
dotaDf.legs.value_counts()
# Out:
# 2    95
# 0    11
# 4     7
# 6     3
# 8     1
# Name: legs, dtype: int64

# %%
poopaloopa = pd.read_csv('https://stepik.org/media/attachments/course/4852/accountancy.csv')

# %%
poopaloopa.head()
# Out:
#    Unnamed: 0 Executor Type  Salary
# 0           0     Pupa    D      63
# 1           1     Pupa    A     158
# 2           2     Pupa    D     194
# 3           3     Pupa    E     109
# 4           4    Loopa    E     184

# %%
poopaloopa.query("Executor == 'Pupa'").groupby('Type', as_index=False).mean()
# Out:
#   Type  Unnamed: 0      Salary
# 0    A       16.00  160.833333
# 1    B       41.00   77.000000
# 2    C       23.00   74.500000
# 3    D       14.00  146.500000
# 4    E       19.80  131.200000
# 5    F       25.75  136.250000

# %%
poopaloopa.query("Executor == 'Loopa'").groupby('Type', as_index=False).mean()
# Out:
#   Type  Unnamed: 0      Salary
# 0    A   46.000000   58.000000
# 1    B   24.000000  145.166667
# 2    C   31.666667  154.333333
# 3    D   31.857143  137.714286
# 4    E   23.500000  164.000000
# 5    F   20.000000  238.000000

# %%
dotaDf.groupby(['attack_type', 'primary_attr']).describe()
# Out:
#                          Unnamed: 0                        ... legs
#                               count       mean        std  ...  50%  75%  max
# attack_type primary_attr                                   ...
# Melee       agi                19.0  61.315789  38.233279  ...  2.0  2.0  8.0
#             int                 2.0  67.500000  20.506097  ...  2.0  2.0  2.0
#             str                35.0  62.657143  34.265351  ...  2.0  2.0  6.0
# Ranged      agi                18.0  46.111111  32.737618  ...  2.0  2.0  4.0
#             int                40.0  55.225000  32.472069  ...  2.0  2.0  6.0
#             str                 3.0  84.666667  25.774665  ...  2.0  2.0  2.0
#
# [6 rows x 24 columns]

# %%
dotaDf.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-7a28fce7ebb6> in <module>()
# ----> 1 dotaDf.head()
#
# NameError: name 'dotaDf' is not defined

# %%
concentrations = pd.read_csv('http://stepik.org/media/attachments/course/4852/algae.csv')

# %%
concentrations.head()
# Out:
#                species       genus  group  ...   citrate   glucose  oleic_acid
# 0    Fucus_vesiculosus       Fucus  brown  ...  5.004262  2.548459    6.405165
# 1  Saccharina_japonica  Saccharina  brown  ...  5.621499  6.013219    4.156700
# 2       Fucus_serratus       Fucus  brown  ...  1.216767  3.623225    0.304573
# 3      Fucus_distichus       Fucus  brown  ...  6.423606  2.272724    3.393203
# 4    Cladophora_fracta  Cladophora  green  ...  6.940588  2.316955    2.528886
#
# [5 rows x 8 columns]

# %%
concentrations.groupby('genus').head()
# Out:
#                 species        genus  group  ...   citrate   glucose  oleic_acid
# 0     Fucus_vesiculosus        Fucus  brown  ...  5.004262  2.548459    6.405165
# 1   Saccharina_japonica   Saccharina  brown  ...  5.621499  6.013219    4.156700
# 2        Fucus_serratus        Fucus  brown  ...  1.216767  3.623225    0.304573
# 3       Fucus_distichus        Fucus  brown  ...  6.423606  2.272724    3.393203
# 4     Cladophora_fracta   Cladophora  green  ...  6.940588  2.316955    2.528886
# 5   Cladophora_compacta   Cladophora  green  ...  3.082826  3.343707    1.432514
# 6   Cladophora_gracilis   Cladophora  green  ...  5.841520  2.740165    2.829016
# 7      Palmaria_palmata     Palmaria    red  ...  5.573905  3.242090    2.245538
# 8  Saccharina_latissima   Saccharina  brown  ...  1.071920  3.947968    4.817804
# 9   Ascophyllum_nodosum  Ascophyllum  brown  ...  5.253527  3.414961    2.432526
#
# [10 rows x 8 columns]

# %%
poopaloopa.groupby(['Executor','Type']).mean()
# Out:
#                Unnamed: 0      Salary
# Executor Type
# Loopa    A      46.000000   58.000000
#          B      24.000000  145.166667
#          C      31.666667  154.333333
#          D      31.857143  137.714286
#          E      23.500000  164.000000
#          F      20.000000  238.000000
# Pupa     A      16.000000  160.833333
#          B      41.000000   77.000000
#          C      23.000000   74.500000
#          D      14.000000  146.500000
#          E      19.800000  131.200000
#          F      25.750000  136.250000

# %%
concentrations.groupby('genus', as_index=False).mean()
# Out:
#          genus   sucrose    alanin   citrate   glucose  oleic_acid
# 0  Ascophyllum  6.825467  0.875429  5.253527  3.414961    2.432526
# 1   Cladophora  4.008792  3.997055  5.288311  2.800276    2.263472
# 2        Fucus  4.355112  3.566411  4.214878  2.814803    3.367647
# 3     Palmaria  0.704580  3.176440  5.573905  3.242090    2.245538
# 4   Saccharina  4.183596  3.524207  3.346710  4.980594    4.487252

# %%
mean_concentrations = concentrations.groupby('genus', as_index=False).mean()

# %%
concentrations.iloc[:]
# Out:
#                 species        genus  group  ...   citrate   glucose  oleic_acid
# 0     Fucus_vesiculosus        Fucus  brown  ...  5.004262  2.548459    6.405165
# 1   Saccharina_japonica   Saccharina  brown  ...  5.621499  6.013219    4.156700
# 2        Fucus_serratus        Fucus  brown  ...  1.216767  3.623225    0.304573
# 3       Fucus_distichus        Fucus  brown  ...  6.423606  2.272724    3.393203
# 4     Cladophora_fracta   Cladophora  green  ...  6.940588  2.316955    2.528886
# 5   Cladophora_compacta   Cladophora  green  ...  3.082826  3.343707    1.432514
# 6   Cladophora_gracilis   Cladophora  green  ...  5.841520  2.740165    2.829016
# 7      Palmaria_palmata     Palmaria    red  ...  5.573905  3.242090    2.245538
# 8  Saccharina_latissima   Saccharina  brown  ...  1.071920  3.947968    4.817804
# 9   Ascophyllum_nodosum  Ascophyllum  brown  ...  5.253527  3.414961    2.432526
#
# [10 rows x 8 columns]

# %%
mean_concentrations.iloc[:]
# Out:
#          genus   sucrose    alanin   citrate   glucose  oleic_acid
# 0  Ascophyllum  6.825467  0.875429  5.253527  3.414961    2.432526
# 1   Cladophora  4.008792  3.997055  5.288311  2.800276    2.263472
# 2        Fucus  4.355112  3.566411  4.214878  2.814803    3.367647
# 3     Palmaria  0.704580  3.176440  5.573905  3.242090    2.245538
# 4   Saccharina  4.183596  3.524207  3.346710  4.980594    4.487252

# %%
concentrations.iloc[:]
# Out:
#                 species        genus  group  ...   citrate   glucose  oleic_acid
# 0     Fucus_vesiculosus        Fucus  brown  ...  5.004262  2.548459    6.405165
# 1   Saccharina_japonica   Saccharina  brown  ...  5.621499  6.013219    4.156700
# 2        Fucus_serratus        Fucus  brown  ...  1.216767  3.623225    0.304573
# 3       Fucus_distichus        Fucus  brown  ...  6.423606  2.272724    3.393203
# 4     Cladophora_fracta   Cladophora  green  ...  6.940588  2.316955    2.528886
# 5   Cladophora_compacta   Cladophora  green  ...  3.082826  3.343707    1.432514
# 6   Cladophora_gracilis   Cladophora  green  ...  5.841520  2.740165    2.829016
# 7      Palmaria_palmata     Palmaria    red  ...  5.573905  3.242090    2.245538
# 8  Saccharina_latissima   Saccharina  brown  ...  1.071920  3.947968    4.817804
# 9   Ascophyllum_nodosum  Ascophyllum  brown  ...  5.253527  3.414961    2.432526
#
# [10 rows x 8 columns]

# %%
concentrations.groupby('group', as_index=False).var()
# Out:
#    group   sucrose    alanin   citrate   glucose  oleic_acid
# 0  brown  5.459098  7.220351  5.468942  1.767756    4.385233
# 1  green  2.672626  7.059917  3.950113  0.266265    0.540388
# 2    red       NaN       NaN       NaN       NaN         NaN

# %%
import pandas as pd
import numpy as np

# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dotaDf.head()
# Out:
#    Unnamed: 0  ...                                              roles
# 0           0  ...                       ['Carry', 'Escape', 'Nuker']
# 1           1  ...    ['Initiator', 'Durable', 'Disabler', 'Jungler']
# 2           2  ...        ['Support', 'Disabler', 'Nuker', 'Durable']
# 3           3  ...  ['Carry', 'Disabler', 'Jungler', 'Nuker', 'Ini...
# 4           4  ...        ['Support', 'Disabler', 'Nuker', 'Jungler']
#
# [5 rows x 8 columns]

# %%
dotaDf.legs.hist()

# %%
studentsPerformance['math score'].hist()

# %%
studentsPerformance.plot.scatter(x='math score', y='reading score')

# %%
ax = sns.lmplot(x='math score', y='reading score', hue='gender', data=studentsPerformance, fit_reg=False)
ax.set_xlabels('MATH Score');

# %%
ax

# %%
income = pd.read_csv('https://stepik.org/media/attachments/course/4852/income.csv')

# %%
income.plot(kind='line')

# %%
income.head()
# Out:
#             income
# 2018-11-30      20
# 2018-12-31      60
# 2019-01-31     180
# 2019-02-28     380
# 2019-03-31     660

# %%
plt.plot(income.index, income.income)

# %%
sns.lineplot(data=income)

# %%
income['income'].plot()

# %%
income.plot()

# %%
income.income.plot()

# %%
sns.lineplot(x=income.index, y=income.income)

# %%
df = pd.read_csv('http://pastie.org/p/4SMp12H9koe1fWO8iMRHQZ/raw', sep=" ")

# %%
df.head()
# Out:
#             x            y
# 0  396.328541  1309.042702
# 1  590.126062   702.542585
# 2   92.093199   399.831081
# 3  893.853099   991.139984
# 4  713.690591   598.829717

# %%
df.plot.scatter(x='x',y='y')

# %%
  g= pd.read_csv('https://stepik.org/media/attachments/course/4852/genome_matrix.csv', index_col=0)

# %%
gheat = sns.heatmap(g, cmap="viridis")

# %%
g.head()
# Out:
#           species0  species1  species2  species3  species4
# species0  0.536029  0.920292  0.679708  0.840606  0.430842
# species1  0.920292  0.862417  0.887593  0.769754  0.203214
# species2  0.679708  0.887593  0.595156  0.003435  0.096052
# species3  0.840606  0.769754  0.003435  0.458870  0.029251
# species4  0.430842  0.203214  0.096052  0.029251  0.642109
