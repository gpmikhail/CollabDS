# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(rc={'figure.figsize': (9,6)})

# %%
dotaRoles = pd.read_csv('https://stepik.org/media/attachments/course/4852/dota_hero_stats.csv', index_col=0)
dotaRoles.head()
# Out:
#   attack_type  ...                                              roles
# 0       Melee  ...                       ['Carry', 'Escape', 'Nuker']
# 1       Melee  ...    ['Initiator', 'Durable', 'Disabler', 'Jungler']
# 2      Ranged  ...        ['Support', 'Disabler', 'Nuker', 'Durable']
# 3       Melee  ...  ['Carry', 'Disabler', 'Jungler', 'Nuker', 'Ini...
# 4      Ranged  ...        ['Support', 'Disabler', 'Nuker', 'Jungler']
#
# [5 rows x 7 columns]

# %%
dotaRoles.groupby('roles').head()
# Out:
#     attack_type  ...                                              roles
# 0         Melee  ...                       ['Carry', 'Escape', 'Nuker']
# 1         Melee  ...    ['Initiator', 'Durable', 'Disabler', 'Jungler']
# 2        Ranged  ...        ['Support', 'Disabler', 'Nuker', 'Durable']
# 3         Melee  ...  ['Carry', 'Disabler', 'Jungler', 'Nuker', 'Ini...
# 4        Ranged  ...        ['Support', 'Disabler', 'Nuker', 'Jungler']
# ..          ...  ...                                                ...
# 112       Melee  ...       ['Carry', 'Escape', 'Disabler', 'Initiator']
# 113      Ranged  ...         ['Support', 'Nuker', 'Disabler', 'Escape']
# 114       Melee  ...  ['Carry', 'Nuker', 'Disabler', 'Durable', 'Esc...
# 115      Ranged  ...         ['Support', 'Nuker', 'Disabler', 'Escape']
# 116       Melee  ...      ['Carry', 'Initiator', 'Disabler', 'Durable']
#
# [117 rows x 7 columns]

# %%
dotaRoles['numberOfRoles'] = dotaRoles.roles.str.split().str.len()

# %%
dotaRoles.head()
# Out:
#   attack_type  ...  numberOfRoles
# 0       Melee  ...              3
# 1       Melee  ...              4
# 2      Ranged  ...              4
# 3       Melee  ...              5
# 4      Ranged  ...              4
#
# [5 rows x 8 columns]

# %%
dotaRoles.hist('numberOfRoles')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f22798a3350>]],
#       dtype=object)

# %%
iris = pd.read_csv('https://stepik.org/media/attachments/course/4852/iris.csv', index_col=0)
iris.head()
# Out:
#    sepal length  sepal width  petal length  petal width  species
# 0           5.1          3.5           1.4          0.2        0
# 1           4.9          3.0           1.4          0.2        0
# 2           4.7          3.2           1.3          0.2        0
# 3           4.6          3.1           1.5          0.2        0
# 4           5.0          3.6           1.4          0.2        0

# %%
sns.kdeplot(data=iris)

# %%
sns.violinplot(y='petal length', data=iris)

# %%
sns.pairplot(data=iris, hue='species')
iris.corr()
# Out:
#               sepal length  sepal width  petal length  petal width   species
# sepal length      1.000000    -0.109369      0.871754     0.817954  0.782561
# sepal width      -0.109369     1.000000     -0.420516    -0.356544 -0.419446
# petal length      0.871754    -0.420516      1.000000     0.962757  0.949043
# petal width       0.817954    -0.356544      0.962757     1.000000  0.956464
# species           0.782561    -0.419446      0.949043     0.956464  1.000000

# %%
my_data=pd.DataFrame({'type':['A','A','B','B'] ,'value':[10,14,12,23] })

# %%
my_data.iloc[:]
# Out:
#   type  value
# 0    A     10
# 1    A     14
# 2    B     12
# 3    B     23

# %%
my_stat = pd.read_csv('https://stepik.org/media/attachments/course/4852/my_stat.csv')
my_stat.head()
# Out:
#    V1    V2 V3   V4
# 0   2  13.0  B  1.0
# 1  -1   7.0  B  1.0
# 2   0  11.0  A  0.0
# 3   2  11.0  A  2.0
# 4   0  10.0  B -1.0

# %%
my_stat.loc[0:9, ['V1','V3']]
# Out:
#    V1 V3
# 0   2  B
# 1  -1  B
# 2   0  A
# 3   2  A
# 4   0  B
# 5   2  A
# 6   0  A
# 7   1  A
# 8   0  B
# 9  -1  A

# %%
excl = my_stat.drop([0,4], axis=0)

# %%
excl.head()
# Out:
#    V1    V2 V3   V4
# 1  -1   7.0  B  1.0
# 2   0  11.0  A  0.0
# 3   2  11.0  A  2.0
# 5   2  11.0  A  0.0
# 6   0   9.0  A  2.0

# %%
my_stat.query('V1 > 0 & V3 == "A"')
# Out:
#      V1    V2 V3   V4
# 3     2  11.0  A  2.0
# 5     2  11.0  A  0.0
# 7     1   9.0  A  1.0
# 10    1  10.0  A  1.0
# 13    1  12.0  A  3.0
# ..   ..   ... ..  ...
# 491   4   7.0  A  2.0
# 494   1  11.0  A  1.0
# 495   1   8.0  A -1.0
# 496   3   8.0  A  1.0
# 498   1  11.0  A  2.0
#
# [88 rows x 4 columns]

# %%
my_stat.query('V2 != 10 | V4 >= 1')
# Out:
#      V1    V2 V3   V4
# 0     2  13.0  B  1.0
# 1    -1   7.0  B  1.0
# 2     0  11.0  A  0.0
# 3     2  11.0  A  2.0
# 5     2  11.0  A  0.0
# ..   ..   ... ..  ...
# 495   1   8.0  A -1.0
# 496   3   8.0  A  1.0
# 497  -1  11.0  B  2.0
# 498   1  11.0  A  2.0
# 499   0   8.0  B  1.0
#
# [447 rows x 4 columns]

# %%
my_stat['V5'] = my_stat.V1 + my_stat.V4

# %%
my_stat.head()
# Out:
#    V1    V2 V3   V4   V5
# 0   2  13.0  B  1.0  3.0
# 1  -1   7.0  B  1.0  0.0
# 2   0  11.0  A  0.0  0.0
# 3   2  11.0  A  2.0  4.0
# 4   0  10.0  B -1.0 -1.0

# %%
my_stat['V6'] = np.log(my_stat.V2)

# %%
my_stat.head()
# Out:
#    V1    V2 V3   V4   V5        V6
# 0   2  13.0  B  1.0  3.0  2.564949
# 1  -1   7.0  B  1.0  0.0  1.945910
# 2   0  11.0  A  0.0  0.0  2.397895
# 3   2  11.0  A  2.0  4.0  2.397895
# 4   0  10.0  B -1.0 -1.0  2.302585

# %%
my_stat.rename(columns={'V1' : 'session_value', 'V2' : 'group', 'V3' : 'time', 'V4' : 'n_users'}, inplace=True)

# %%
my_stat.session_value.fillna(0, inplace=True)

# %%
mystat1 = pd.read_csv('https://stepik.org/media/attachments/course/4852/my_stat_1.csv')

# %%
mystat1.head()
# Out:
#    session_value  time group  n_users
# 0            0.0    12     B        9
# 1            NaN    11     A       -1
# 2            1.0     8     A        1
# 3            2.0     9     B        3
# 4            2.0    10     B        9

# %%
mystat1.session_value.fillna(0, inplace=True)

# %%
mystat1.head()
# Out:
#    session_value  time group  n_users
# 0            0.0    12     B        9
# 1            0.0    11     A       -1
# 2            1.0     8     A        1
# 3            2.0     9     B        3
# 4            2.0    10     B        9

# %%
queryExclNeg= mystat1.query('n_users >= 0')
queryExclNeg.head()
# Out:
#    session_value  time group  n_users
# 0            0.0    12     B        9
# 2            1.0     8     A        1
# 3            2.0     9     B        3
# 4            2.0    10     B        9
# 5            3.0     8     A        8

# %%
queryExclNeg= mystat1.query('n_users >= 0')
queryNeg= mystat1.query('n_users < 0')
queryExclNeg.iloc[:]
# Out:
#    session_value  time group  n_users
# 0            0.0    12     B        9
# 2            1.0     8     A        1
# 3            2.0     9     B        3
# 4            2.0    10     B        9
# 5            3.0     8     A        8
# 6            0.0    11     B        5
# 7            0.0     9     A        4

# %%
med = queryExclNeg.n_users.median()
print(med)
# Out:
# 5.0

# %%
mystat1.loc[mystat1['n_users']<0,'n_users'] = med

# %%
mystat1.iloc[:]
# Out:
#    session_value  time group  n_users
# 0            0.0    12     B        9
# 1            0.0    11     A        5
# 2            1.0     8     A        1
# 3            2.0     9     B        3
# 4            2.0    10     B        9
# 5            3.0     8     A        8
# 6            0.0    11     B        5
# 7            0.0     9     A        4
# 8            0.0     8     B        5
# 9            0.0     9     A        5

# %%
med = queryExclNeg['n_users'].median()

# %%
print(med)
# Out:
# 5.0

# %%
M = mystat1[mystat1.n_users >= 0.0].n_users.median()

# %%
print(M)
# Out:
# 5.0

# %%
mystat1.groupby('group', as_index=False).session_value.mean().rename(columns={"session_value" : "mean_session_value"})
# Out:
#   group  mean_session_value
# 0     A                 0.8
# 1     B                 0.8

# %%
events_data = pd.read_csv('https://stepik.org/media/attachments/course/4852/event_data_train.zip', compression ='zip')

# %%
events_data.head()
# Out:
#    step_id   timestamp      action  user_id
# 0    32815  1434340848      viewed    17632
# 1    32815  1434340848      passed    17632
# 2    32815  1434340848  discovered    17632
# 3    32811  1434340895  discovered    17632
# 4    32811  1434340895      viewed    17632

# %%
events_data.action.unique()
# Out:
# array(['viewed', 'passed', 'discovered', 'started_attempt'], dtype=object)

# %%
events_data['date'] = pd.to_datetime(events_data.timestamp, unit='s')

# %%
events_data.head(10)
# Out:
#    step_id   timestamp           action  user_id                date
# 0    32815  1434340848           viewed    17632 2015-06-15 04:00:48
# 1    32815  1434340848           passed    17632 2015-06-15 04:00:48
# 2    32815  1434340848       discovered    17632 2015-06-15 04:00:48
# 3    32811  1434340895       discovered    17632 2015-06-15 04:01:35
# 4    32811  1434340895           viewed    17632 2015-06-15 04:01:35
# 5    32811  1434340895           passed    17632 2015-06-15 04:01:35
# 6    32929  1434340921       discovered    17632 2015-06-15 04:02:01
# 7    32929  1434340921           viewed    17632 2015-06-15 04:02:01
# 8    32929  1434340939  started_attempt    17632 2015-06-15 04:02:19
# 9    32929  1434340944           passed    17632 2015-06-15 04:02:24

# %%
events_data['day'] = events_data.date.dt.date

# %%
events_data.head()
# Out:
#    step_id   timestamp      action  user_id                date         day
# 0    32815  1434340848      viewed    17632 2015-06-15 04:00:48  2015-06-15
# 1    32815  1434340848      passed    17632 2015-06-15 04:00:48  2015-06-15
# 2    32815  1434340848  discovered    17632 2015-06-15 04:00:48  2015-06-15
# 3    32811  1434340895  discovered    17632 2015-06-15 04:01:35  2015-06-15
# 4    32811  1434340895      viewed    17632 2015-06-15 04:01:35  2015-06-15

# %%
events_data.groupby('day') \
  .user_id.nunique().plot()

# %%
#events_data[events_data.action == 'passed'] \
#  .groupby('user_id', as_index=False) \
#  .agg({'step_id': 'count'}) \
#  .rename(columns={'step_id' : 'passed_steps'}).passed_steps.hist()

# %%
users_events_data = events_data.pivot_table(index='user_id', columns='action', values='step_id', aggfunc='count', fill_value=0).reset_index()

# %%
users_events_data.head()
# Out:
# action  user_id  discovered  passed  started_attempt  viewed
# 0             1           1       0                0       1
# 1             2           9       9                2      10
# 2             3          91      87               30     192
# 3             5          11      11                4      12
# 4             7           1       1                0       1

# %%
submissions_data = pd.read_csv('https://stepik.org/media/attachments/course/4852/submissions_data_train.zip',compression ='zip')

# %%
submissions_data.head()
# Out:
#    step_id   timestamp submission_status  user_id
# 0    31971  1434349275           correct    15853
# 1    31972  1434348300           correct    15853
# 2    31972  1478852149             wrong    15853
# 3    31972  1478852164           correct    15853
# 4    31976  1434348123             wrong    15853

# %%
submissions_data['date'] = pd.to_datetime(submissions_data.timestamp, unit='s')
submissions_data['day'] = submissions_data.date.dt.date

# %%
user_scores = submissions_data.pivot_table(index='user_id', columns='submission_status', values='step_id', aggfunc='count', fill_value=0).reset_index()

# %%
user_scores.head()
# Out:
# submission_status  user_id  correct  wrong
# 0                        2        2      0
# 1                        3       29     23
# 2                        5        2      2
# 3                        8        9     21
# 4                       14        0      1

# %%
gap_data = events_data[['user_id', 'day', 'timestamp']].drop_duplicates(subset=['user_id', 'day']) \
  .groupby('user_id')['timestamp'].apply(list) \
  .apply(np.diff).values

# %%
gap_data = pd.Series(np.concatenate(gap_data, axis=0))

# %%
gap_data = gap_data / (24*60*60)

# %%
gap_data.hist()

# %%
user_scores.max()
# Out:
# submission_status
# user_id    26798
# correct      421
# wrong       1001
# dtype: int64

# %%
user_scores.sort_values(by='correct', ascending=False)
# Out:
# submission_status  user_id  correct  wrong
# 439                   1046      421    513
# 2099                  5552      186     93
# 6415                 17135      168    177
# 2344                  6183      142     65
# 3208                  8461      135     42
# ...                    ...      ...    ...
# 551                   1321        0      2
# 9778                 26349        0      1
# 3559                  9422        0      1
# 5014                 13408        0      2
# 6377                 17033        0      3
#
# [9940 rows x 3 columns]

# %%
user_data = events_data.groupby('user_id', as_index=False) \
  .agg({'timestamp' : 'max'}).rename(columns={'timestamp' : 'last_timestamp'})

# %%
now = 1526772811
drop_out_treshold = 2592000

# %%
user_data['is_gone_user'] = now - user_data.last_timestamp > drop_out_treshold

# %%
events_data.tail()
# Out:
#          step_id   timestamp  ...                date         day
# 3480698    33375  1526772685  ... 2018-05-19 23:31:25  2018-05-19
# 3480699    32815  1526772750  ... 2018-05-19 23:32:30  2018-05-19
# 3480700    32815  1526772750  ... 2018-05-19 23:32:30  2018-05-19
# 3480701    32815  1526772750  ... 2018-05-19 23:32:30  2018-05-19
# 3480702    33892  1526772811  ... 2018-05-19 23:33:31  2018-05-19
#
# [5 rows x 6 columns]

# %%
user_data.head()
# Out:
#    user_id  last_timestamp  is_gone_user
# 0        1      1472827464          True
# 1        2      1519226966          True
# 2        3      1444581588          True
# 3        5      1499859939          True
# 4        7      1521634660          True

# %%
now = 1526772811
drop_out_treshold = 30*24*60*60

# %%
user_data.head()
# Out:
#    user_id  last_timestamp  is_gone_user
# 0        1      1472827464          True
# 1        2      1519226966          True
# 2        3      1444581588          True
# 3        5      1499859939          True
# 4        7      1521634660          True

# %%
user_scores.head()
# Out:
# submission_status  user_id  correct  wrong
# 0                        2        2      0
# 1                        3       29     23
# 2                        5        2      2
# 3                        8        9     21
# 4                       14        0      1

# %%
user_data = user_data.merge(user_scores, how='outer')

# %%
user_data = user_data.fillna(0)

# %%
user_data.head()
# Out:
#    user_id  last_timestamp  is_gone_user  correct  wrong
# 0        1      1472827464          True      0.0    0.0
# 1        2      1519226966          True      2.0    0.0
# 2        3      1444581588          True     29.0   23.0
# 3        5      1499859939          True      2.0    2.0
# 4        7      1521634660          True      0.0    0.0

# %%
user_data = user_data.merge(users_events_data, how='outer')

# %%
user_data.head()
# Out:
#    user_id  last_timestamp  is_gone_user  ...  passed  started_attempt  viewed
# 0        1      1472827464          True  ...       0                0       1
# 1        2      1519226966          True  ...       9                2      10
# 2        3      1444581588          True  ...      87               30     192
# 3        5      1499859939          True  ...      11                4      12
# 4        7      1521634660          True  ...       1                0       1
#
# [5 rows x 9 columns]

# %%
users_days =  events_data.groupby('user_id').day.nunique().to_frame().reset_index()

# %%
users_days.head()
# Out:
#    user_id  day
# 0        1    1
# 1        2    2
# 2        3    7
# 3        5    2
# 4        7    1

# %%
user_data = user_data.merge(users_days, how='outer')

# %%
user_data.head()
# Out:
#    user_id  last_timestamp  is_gone_user  ...  started_attempt  viewed  day
# 0        1      1472827464          True  ...                0       1    1
# 1        2      1519226966          True  ...                2      10    2
# 2        3      1444581588          True  ...               30     192    7
# 3        5      1499859939          True  ...                4      12    2
# 4        7      1521634660          True  ...                0       1    1
#
# [5 rows x 10 columns]

# %%
user_data['passed_courses'] = user_data.passed > 170

# %%
user_data.groupby('passed_courses').count()
# Out:
#                 user_id  last_timestamp  ...  viewed    day
# passed_courses                           ...
# False             17809           17809  ...   17809  17809
# True               1425            1425  ...    1425   1425
#
# [2 rows x 10 columns]

# %%
user_data[user_data.passed_courses].day.hist()

# %%
user_min_time = events_data.groupby('user_id', as_index=False) \
  .agg({'timestamp': 'min'}) \
  .rename({'timestamp':'min_timestamp'}, axis=1)

# %%
 user_min_time.head()
# Out:
#    user_id  min_timestamp
# 0        1     1472827464
# 1        2     1514383364
# 2        3     1434358476
# 3        5     1466156809
# 4        7     1521634660

# %%
user_data = user_data.merge(user_min_time, how='outer')

# %%
events_data['user_time'] = events_data.user_id.map(str) + '_' + events_data.timestamp.map(str)

# %%
learning_time_treshold = 3 * 24 * 60 * 60

# %%
user_min_time
# Out:
#        user_id  min_timestamp
# 0            1     1472827464
# 1            2     1514383364
# 2            3     1434358476
# 3            5     1466156809
# 4            7     1521634660
# ...        ...            ...
# 19229    26790     1451484016
# 19230    26793     1510225031
# 19231    26794     1495287049
# 19232    26797     1508425316
# 19233    26798     1520975763
#
# [19234 rows x 2 columns]

# %%
user_learning_time_treshold = user_min_time.user_id.map(str) + '_' + (user_min_time.min_timestamp + learning_time_treshold).map(str)

# %%
user_min_time['user_learning_time_treshold'] = user_learning_time_treshold

# %%
events_data = events_data.merge(user_min_time[['user_id', 'user_learning_time_treshold']], how='outer')

# %%
events_data_train = events_data[events_data.user_time <= events_data.user_learning_time_treshold]

# %%
submissions_data.head()
# Out:
#    step_id   timestamp  ...                date         day
# 0    31971  1434349275  ... 2015-06-15 06:21:15  2015-06-15
# 1    31972  1434348300  ... 2015-06-15 06:05:00  2015-06-15
# 2    31972  1478852149  ... 2016-11-11 08:15:49  2016-11-11
# 3    31972  1478852164  ... 2016-11-11 08:16:04  2016-11-11
# 4    31976  1434348123  ... 2015-06-15 06:02:03  2015-06-15
#
# [5 rows x 6 columns]

# %%
events_data.head()
# Out:
#    step_id   timestamp  ...         user_time  user_learning_time_treshold
# 0    32815  1434340848  ...  17632_1434340848             17632_1434600048
# 1    32815  1434340848  ...  17632_1434340848             17632_1434600048
# 2    32815  1434340848  ...  17632_1434340848             17632_1434600048
# 3    32811  1434340895  ...  17632_1434340895             17632_1434600048
# 4    32811  1434340895  ...  17632_1434340895             17632_1434600048
#
# [5 rows x 8 columns]

# %%
submissions = submissions_data.drop(columns=['date', 'day'])

# %%
submissions = pd.get_dummies(submissions, columns=['submission_status'])

# %%
last_time = submissions.groupby('user_id').agg({'timestamp': 'max'}).rename(columns={'timestamp':'last_timestamp'})

# %%
last_step_id = submissions.groupby('user_id').agg({'step_id':'max'}).rename(columns={'step_id':'last_step_id'})

# %%
submissions = submissions.merge(last_time, on='user_id')

# %%
submissions = submissions.merge(last_step_id, on='user_id')

# %%
submissions_data.query('submission_status == "wrong"').groupby('step_id').agg({'submission_status':'count'}).sort_values(by='submission_status', ascending=False)
# Out:
#          submission_status
# step_id
# 31978                16084
# 32031                13373
# 32202                13002
# 33481                10300
# 32075                10003
# ...                    ...
# 33482                  707
# 33681                  703
# 33362                  673
# 32175                  342
# 32929                   85
#
# [76 rows x 1 columns]

# %%
submissions_data.step_id.mode()
# Out:
# 0    31978
# dtype: int64

# %%
submissions_data['users_time'] = submissions_data.user_id.map(str) + '_' + submissions_data.timestamp.map(str)

# %%
submissions_data =  submissions_data.merge(user_min_time[['user_id', 'user_learning_time_threshold']], how='outer')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-104-a282af756a6c> in <module>()
# ----> 1 submissions_data =  submissions_data.merge(user_min_time[['user_id', 'user_learning_time_threshold']], how='outer')
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    2910             if is_iterator(key):
#    2911                 key = list(key)
# -> 2912             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2913
#    2914         # take() does not accept boolean indexers
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1252             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1253
# -> 1254         self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
# ...

# %%
submissions_data_train = submissions_data[submissions_data.users_time <= submissions_data.user_learning_time_threshold]

# %%
submissions_data_train.groupby('user_id').day.nunique().max()

# %%
X=0

# %%
submissions_data = submissions_data.merge(user_min_time, on='user_id', how='left')
# Время от первого степа до последнего
submissions_data['users_time'] = submissions_data['timestamp'] - submissions_data['min_timestamp']
#Выбираем степы первых трёх дней
submissions_data_train = submissions_data[submissions_data.users_time <= 3*24*60*60]
submissions_data_train.groupby('user_id').day.nunique().max()
# Out:
# 4

# %%
X = submissions_data_train.groupby('user_id').day.nunique().to_frame().reset_index() \
  .rename(columns={'day':'days'})

# %%
X.head()
# Out:
#    user_id  days
# 0        2     1
# 1        3     1
# 2        8     1
# 3       14     1
# 4       16     3

# %%
steps_tried = submissions_data_train.groupby('user_id').step_id.nunique().to_frame().reset_index() \
  .rename(columns={'step_id':'steps_tried'})

# %%
steps_tried.head()
# Out:
#    user_id  steps_tried
# 0        2            2
# 1        3            4
# 2        8           11
# 3       14            1
# 4       16           23

# %%
X = X.merge(steps_tried, on='user_id', how='outer')

# %%
steps_tried = 0

# %%
X = 0

# %%
X.head()
# Out:
#    user_id  days  steps_tried
# 0        2     1            2
# 1        3     1            4
# 2        8     1           11
# 3       14     1            1
# 4       16     3           23

# %%
X.shape
# Out:
# (8913, 3)

# %%
X = X.merge(submissions_data_train.pivot_table(index='user_id',
  columns='submission_status',
  values='step_id',
  aggfunc='count',
  fill_value=0).reset_index())

# %%
X['correct_ratio'] = X.correct / (X.correct + X.wrong)

# %%
X = X.merge(events_data_train.pivot_table(index='user_id',
                                          columns='action',
                                          values='step_id',
                                          aggfunc='count',
                                          fill_value=0).reset_index()[['user_id', 'viewed']], how='outer')

# %%
X.head()
# Out:
#    user_id  days  steps_tried  correct  wrong  correct_ratio  viewed
# 0        2   1.0          2.0      2.0    0.0           1.00       9
# 1        3   1.0          4.0      4.0    4.0           0.50      20
# 2        8   1.0         11.0      9.0   21.0           0.30     154
# 3       14   1.0          1.0      0.0    1.0           0.00       9
# 4       16   3.0         23.0     23.0   27.0           0.46     132

# %%
events_data_train.query('action == "viewed" & user_id == "2"').head(15)
# Out:
#          step_id   timestamp  ...     user_time  user_learning_time_treshold
# 3040122    32815  1514383364  ...  2_1514383364                 2_1514642564
# 3040126    32811  1514383372  ...  2_1514383372                 2_1514642564
# 3040127    32929  1514383396  ...  2_1514383396                 2_1514642564
# 3040131    32814  1514383426  ...  2_1514383426                 2_1514642564
# 3040135    32812  1514383469  ...  2_1514383469                 2_1514642564
# 3040139    32816  1514383491  ...  2_1514383491                 2_1514642564
# 3040141    32930  1514383510  ...  2_1514383510                 2_1514642564
# 3040144    32979  1514383515  ...  2_1514383515                 2_1514642564
# 3040147    32927  1514383555  ...  2_1514383555                 2_1514642564
#
# [9 rows x 8 columns]

# %%
X = X.fillna(0)

# %%
# Out:
#    user_id  days  steps_tried  ...  passed  started_attempt  viewed
# 0        2   1.0          2.0  ...       9                2       9
# 1        3   1.0          4.0  ...      15                4      20
# 2        8   1.0         11.0  ...      84               37     154
# 3       14   1.0          1.0  ...       3                1       9
# 4       16   3.0         23.0  ...      55               26     132
#
# [5 rows x 10 columns]

# %%
user_data.head()
# Out:
#    user_id  last_timestamp  is_gone_user  ...  day  passed_courses  min_timestamp
# 0        1      1472827464          True  ...    1           False     1472827464
# 1        2      1519226966          True  ...    2           False     1514383364
# 2        3      1444581588          True  ...    7           False     1434358476
# 3        5      1499859939          True  ...    2           False     1466156809
# 4        7      1521634660          True  ...    1           False     1521634660
#
# [5 rows x 12 columns]

# %%
X = X.merge(user_data[['user_id','passed_courses', 'is_gone_user']], how='outer')

# %%
X = X[~((X.is_gone_user == False) & (X.passed_courses == False))]

# %%
X.head()
# Out:
#    user_id  days  steps_tried  ...  viewed  passed_courses  is_gone_user
# 0        2   1.0          2.0  ...       9           False          True
# 1        3   1.0          4.0  ...      20           False          True
# 2        8   1.0         11.0  ...     154           False          True
# 3       14   1.0          1.0  ...       9           False          True
# 4       16   3.0         23.0  ...     132            True          True
#
# [5 rows x 9 columns]

# %%
y = X.passed_courses.map(int)

# %%
X = X.drop(['passed_courses', 'is_gone_user'], axis=1)

# %%
X = X.set_index(X.user_id)

# %%
X.head()
# Out:
#          user_id  days  steps_tried  correct  wrong  correct_ratio  viewed
# user_id
# 2              2   1.0          2.0      2.0    0.0           1.00       9
# 3              3   1.0          4.0      4.0    4.0           0.50      20
# 8              8   1.0         11.0      9.0   21.0           0.30     154
# 14            14   1.0          1.0      0.0    1.0           0.00       9
# 16            16   3.0         23.0     23.0   27.0           0.46     132

# %%
X.drop('user_id', axis=1)
# Out:
#          days  steps_tried  correct  wrong  correct_ratio  viewed
# user_id
# 2         1.0          2.0      2.0    0.0           1.00       9
# 3         1.0          4.0      4.0    4.0           0.50      20
# 8         1.0         11.0      9.0   21.0           0.30     154
# 14        1.0          1.0      0.0    1.0           0.00       9
# 16        3.0         23.0     23.0   27.0           0.46     132
# ...       ...          ...      ...    ...            ...     ...
# 26774     0.0          0.0      0.0    0.0           0.00       1
# 26781     0.0          0.0      0.0    0.0           0.00       6
# 26788     0.0          0.0      0.0    0.0           0.00       1
# 26789     0.0          0.0      0.0    0.0           0.00       2
# 26793     0.0          0.0      0.0    0.0           0.00       1
#
# [17985 rows x 6 columns]
