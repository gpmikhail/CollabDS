# %%
from sklearn import tree
from sklearn.tree import plot_tree
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import confusion_matrix
from sklearn.metrics import precision_score, recall_score
from IPython.display import SVG, display
from sklearn.ensemble import RandomForestClassifier
from sklearn.datasets import make_classification
from time import time
import pandas as pd
import math
import requests, zipfile, io
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
# %matplotlib inline

# %%
data = pd.DataFrame({'X_1': [1, 1, 1, 0, 0, 0, 0, 1], 'X_2': [0, 0, 0, 1, 0, 0, 0, 1], 'Y': [1, 1, 1, 1, 0, 0, 0, 0]})

# %%
data
# Out:
#    X_1  X_2  Y
# 0    1    0  1
# 1    1    0  1
# 2    1    0  1
# 3    0    1  1
# 4    0    0  0
# 5    0    0  0
# 6    0    0  0
# 7    1    1  0

# %%
clf = tree.DecisionTreeClassifier(criterion='entropy')

# %%
clf
# Out:
# DecisionTreeClassifier(criterion='entropy')

# %%
X = data[['X_1', 'X_2']]
y = data.Y

# %%
clf.fit(X, y)
# Out:
# DecisionTreeClassifier(criterion='entropy')

# %%
plot_tree(clf, filled=True)
# Out:
# [Text(167.4, 181.2, 'X[0] <= 0.5\nentropy = 1.0\nsamples = 8\nvalue = [4, 4]'),
#  Text(83.7, 108.72, 'X[1] <= 0.5\nentropy = 0.811\nsamples = 4\nvalue = [3, 1]'),
#  Text(41.85, 36.23999999999998, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(125.55000000000001, 36.23999999999998, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(251.10000000000002, 108.72, 'X[1] <= 0.5\nentropy = 0.811\nsamples = 4\nvalue = [1, 3]'),
#  Text(209.25, 36.23999999999998, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(292.95, 36.23999999999998, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]')]

# %%
E_sh_sob=(1/1)*np.log2((1/1)) - 0
E_sh_kot=-(4/9)*np.log2((4/9)) - (5/9)*np.log2((5/9))
E_gav_sob=0 - (5/5)*np.log2((5/5))
E_gav_kot=-(4/5)*np.log2((4/5)) - (1/5)*np.log2((1/5))
E_laz_sob=0 - (6/6)*np.log2((6/6))
E_laz_kot=-(4/4)*np.log2((4/4)) - 0

# %%
E_sh_sob
# Out:
# 0.0

# %%
E_sh_kot
# Out:
# 0.9910760598382222

# %%
E_gav_sob
# Out:
# 0.0

# %%
E_gav_kot
# Out:
# 0.7219280948873623

# %%
E_laz_sob
# Out:
# 0.0

# %%
E_laz_kot
# Out:
# -0.0

# %%
EY = - 4/10 * np.log2(4/10) - 6/10 * np.log2(6/10)

# %%
EY
# Out:
# 0.9709505944546686

# %%
EXYsh = 1/10 * 0.0 + 9/10 * 0.99

# %%
EXYsh
# Out:
# 0.891

# %%
EY - EXYsh
# Out:
# 0.07995059445466857

# %%
EXYgav = 5/10 * 0  + 5/10 * 0.72

# %%
EXYgav
# Out:
# 0.36

# %%
EY - EXYgav
# Out:
# 0.6109505944546686

# %%
titanic = pd.read_csv('https://stepik.org/media/attachments/course/4852/titanic.csv')

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0            1         0       3  ...   7.2500   NaN         S
# 1            2         1       1  ...  71.2833   C85         C
# 2            3         1       3  ...   7.9250   NaN         S
# 3            4         1       1  ...  53.1000  C123         S
# 4            5         0       3  ...   8.0500   NaN         S
#
# [5 rows x 12 columns]

# %%
titanic.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
X = titanic.drop(['PassengerId', 'Survived', 'Name', 'Ticket', 'Cabin'], axis=1)
y = titanic.Survived

# %%
clf = tree.DecisionTreeClassifier(criterion='entropy')

# %%
X = pd.get_dummies(X)

# %%
X.head()
# Out:
#    Pclass   Age  SibSp  Parch  ...  Sex_male  Embarked_C  Embarked_Q  Embarked_S
# 0       3  22.0      1      0  ...         1           0           0           1
# 1       1  38.0      1      0  ...         0           1           0           0
# 2       3  26.0      0      0  ...         0           0           0           1
# 3       1  35.0      1      0  ...         0           0           0           1
# 4       3  35.0      0      0  ...         1           0           0           1
#
# [5 rows x 10 columns]

# %%
X = X.fillna({'Age' : X.Age.median()})

# %%
clf.fit(X,y)
# Out:
# DecisionTreeClassifier(criterion='entropy')

# %%
plt.figure(figsize=(100, 25))
tree.plot_tree(clf, fontsize=10, feature_names=list(X), filled=True)
# Out:
# [Text(3425.755543428309, 1325.025, 'Sex_female <= 0.5\nentropy = 0.961\nsamples = 891\nvalue = [549, 342]'),
#  Text(2170.311638327206, 1257.075, 'Fare <= 26.269\nentropy = 0.699\nsamples = 577\nvalue = [468, 109]'),
#  Text(1081.3493795955883, 1189.125, 'Age <= 13.5\nentropy = 0.558\nsamples = 415\nvalue = [361, 54]'),
#  Text(379.52205882352945, 1121.175, 'SibSp <= 2.0\nentropy = 0.567\nsamples = 15\nvalue = [2, 13]'),
#  Text(338.49264705882354, 1053.225, 'Age <= 10.0\nentropy = 0.371\nsamples = 14\nvalue = [1, 13]'),
#  Text(297.4632352941177, 985.275, 'entropy = 0.0\nsamples = 12\nvalue = [0, 12]'),
#  Text(379.52205882352945, 985.275, 'SibSp <= 0.5\nentropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(338.49264705882354, 917.325, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(420.5514705882353, 917.325, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(420.5514705882353, 1053.225, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state = 42)

# %%
clf.score(X,y)
# Out:
# 0.9797979797979798

# %%
clf.score(X_train, y_train)
# Out:
# 0.9714765100671141

# %%
clf = tree.DecisionTreeClassifier(criterion='entropy', max_depth=3)

# %%
clf.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=3)

# %%
clf.score(X_test, y_test)
# Out:
# 0.8203389830508474

# %%
max_depth_values = range(1,100)

# %%
scores_data = pd.DataFrame()

# %%
for max_depth in max_depth_values:
  clf = tree.DecisionTreeClassifier(criterion='entropy', max_depth=max_depth)
  clf.fit(X_train, y_train)
  train_score = clf.score(X_train, y_train)
  test_score = clf.score(X_test, y_test)

  mean_cross_val_score = cross_val_score(clf, X_train, y_train, cv=5).mean()
  temp_score = pd.DataFrame({'max_depth':[max_depth], 'train_score' : [train_score], 'test_score':[test_score], 'cross_val_score': [mean_cross_val_score]})
  scores_data = scores_data.append(temp_score)

# %%
scores_data.head()
# Out:
#    max_depth  train_score  test_score  cross_val_score
# 0          1     0.781879    0.796610         0.781961
# 0          2     0.805369    0.776271         0.770196
# 0          3     0.823826    0.820339         0.790322
# 0          4     0.833893    0.823729         0.788627
# 0          5     0.840604    0.806780         0.800392

# %%
scores_data_long = pd.melt(scores_data, id_vars=['max_depth'], value_vars=['train_score', 'test_score', 'cross_val_score'],
                           var_name='set_type', value_name='score')

# %%
scores_data_long.head()
# Out:
#    max_depth     set_type     score
# 0          1  train_score  0.781879
# 1          2  train_score  0.805369
# 2          3  train_score  0.823826
# 3          4  train_score  0.833893
# 4          5  train_score  0.840604

# %%
scores_data_long.query("set_type == 'cross_val_score'").head()
# Out:
#      max_depth         set_type     score
# 198          1  cross_val_score  0.781961
# 199          2  cross_val_score  0.770196
# 200          3  cross_val_score  0.790322
# 201          4  cross_val_score  0.788627
# 202          5  cross_val_score  0.800392

# %%
sns.lineplot(x="max_depth", y="score", hue="set_type", data=scores_data_long)

# %%
 best_clf = tree.DecisionTreeClassifier(criterion='entropy', max_depth=10)

# %%
cross_val_score(best_clf, X_test, y_test, cv=5).mean()
# Out:
# 0.7966101694915254

# %%
 clf = tree.DecisionTreeClassifier()
 clf
# Out:
# DecisionTreeClassifier()

# %%
parameters = {'criterion': ['gini', 'entropy'], 'max_depth':range(1,30)}

# %%
grid_search_cv_clf = GridSearchCV(clf, parameters, cv=5)

# %%
grid_search_cv_clf.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': range(1, 30)})

# %%
grid_search_cv_clf.best_params_
# Out:
# {'criterion': 'entropy', 'max_depth': 14}

# %%
best_clf = grid_search_cv_clf.best_estimator_

# %%
best_clf.score(X_test, y_test)
# Out:
# 0.7796610169491526

# %%
y_pred = best_clf.predict(X_test)

# %%
precision_score(y_test, y_pred )
# Out:
# 0.7165354330708661

# %%
recall_score(y_test, y_pred )
# Out:
# 0.7583333333333333

# %%
y_predicted_prob = best_clf.predict_proba(X_test)

# %%
pd.Series(y_predicted_prob[:, 1]).hist()

# %%
 y_pred = np.where(y_predicted_prob[:, 1]> 0.8, 1, 0)

# %%
precision_score(y_test, y_pred )
# Out:
# 0.7142857142857143

# %%
from sklearn.metrics import roc_curve, auc
fpr, tpr, thresholds = roc_curve(y_test, y_predicted_prob[:,1])
roc_auc= auc(fpr, tpr)
plt.figure()
plt.plot(fpr, tpr, color='darkorange',
          label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic example')
plt.legend(loc="lower right")
plt.show()

# %%
clf = tree.DecisionTreeClassifier(criterion='entropy', max_depth=3, min_samples_split=100, min_samples_leaf=10)

# %%
clf.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=3, min_samples_leaf=10,
#                        min_samples_split=100)

# %%
plt.figure(figsize=(10, 10))
tree.plot_tree(clf, fontsize=10, feature_names=list(X), filled=True)
# Out:
# [Text(279.0, 475.65000000000003, 'Sex_male <= 0.5\nentropy = 0.953\nsamples = 596\nvalue = [374, 222]'),
#  Text(167.39999999999998, 339.75, 'Pclass <= 2.5\nentropy = 0.851\nsamples = 206\nvalue = [57, 149]'),
#  Text(111.6, 203.85000000000002, 'Fare <= 149.035\nentropy = 0.23\nsamples = 107\nvalue = [4, 103]'),
#  Text(55.8, 67.94999999999999, 'entropy = 0.149\nsamples = 94\nvalue = [2, 92]'),
#  Text(167.39999999999998, 67.94999999999999, 'entropy = 0.619\nsamples = 13\nvalue = [2, 11]'),
#  Text(223.2, 203.85000000000002, 'entropy = 0.996\nsamples = 99\nvalue = [53, 46]'),
#  Text(390.59999999999997, 339.75, 'Age <= 3.5\nentropy = 0.696\nsamples = 390\nvalue = [317, 73]'),
#  Text(334.79999999999995, 203.85000000000002, 'entropy = 0.779\nsamples = 13\nvalue = [3, 10]'),
#  Text(446.4, 203.85000000000002, 'Fare <= 52.277\nentropy = 0.651\nsamples = 377\nvalue = [314, 63]'),
#  Text(390.59999999999997, 67.94999999999999, 'entropy = 0.58\nsamples = 332\nvalue = [286, 46]'),
# ...

# %%
clf_rf = RandomForestClassifier()

# %%
parameters = {'n_estimators':[10,20,30], 'max_depth':[2,5,7,10]}

# %%
grid_search_cv_clf = GridSearchCV(clf_rf, parameters, cv = 5)

# %%
grid_search_cv_clf.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestClassifier(),
#              param_grid={'max_depth': [2, 5, 7, 10],
#                          'n_estimators': [10, 20, 30]})

# %%
grid_search_cv_clf.best_params_
# Out:
# {'max_depth': 7, 'n_estimators': 20}

# %%
best_clf = grid_search_cv_clf.best_estimator_

# %%
feature_importances = best_clf.feature_importances_

# %%
feature_importances_df = pd.DataFrame({'features':list(X_train),
                                       'feature_importances':feature_importances})

# %%
feature_importances_df.head()
# Out:
#   features  feature_importances
# 0   Pclass             0.121020
# 1      Age             0.146658
# 2    SibSp             0.049005
# 3    Parch             0.041426
# 4     Fare             0.165410

# %%
feature_importances_df.sort_values('feature_importances', ascending=False)
# Out:
#      features  feature_importances
# 6    Sex_male             0.281181
# 4        Fare             0.165410
# 1         Age             0.146658
# 5  Sex_female             0.138086
# 0      Pclass             0.121020
# 2       SibSp             0.049005
# 3       Parch             0.041426
# 9  Embarked_S             0.031292
# 7  Embarked_C             0.015907
# 8  Embarked_Q             0.010014

# %%
heart_df = pd.read_csv('https://cdn-108.anonfiles.com/B3Wf46W6uc/8047e5f4-1637527654/archive.zip',compression='zip' )

# %%
heart_df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  ...  exang  oldpeak  slope  ca  thal  target
# 0   63    1   3       145   233    1  ...      0      2.3      0   0     1       1
# 1   37    1   2       130   250    0  ...      0      3.5      0   0     2       1
# 2   41    0   1       130   204    0  ...      0      1.4      2   0     2       1
# 3   56    1   1       120   236    0  ...      0      0.8      2   0     2       1
# 4   57    0   0       120   354    0  ...      1      0.6      2   0     2       1
#
# [5 rows x 14 columns]

# %%
y_train = heart_df.target

# %%
X_train = heart_df.drop(columns={'target'}, axis=1)

# %%
X_train.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  ...  thalach  exang  oldpeak  slope  ca  thal
# 0   63    1   3       145   233    1  ...      150      0      2.3      0   0     1
# 1   37    1   2       130   250    0  ...      187      0      3.5      0   0     2
# 2   41    0   1       130   204    0  ...      172      0      1.4      2   0     2
# 3   56    1   1       120   236    0  ...      178      0      0.8      2   0     2
# 4   57    0   0       120   354    0  ...      163      1      0.6      2   0     2
#
# [5 rows x 13 columns]

# %%
np.random.seed(0)

rf = RandomForestClassifier(10, max_depth=5)

# %%
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_depth=5, n_estimators=10)

# %%
feature_importances = rf.feature_importances_

# %%
feature_importances_df = pd.DataFrame({'features':list(X_train),
                                       'feature_importances':feature_importances})

# %%
feature_importances_df.head()
# Out:
#    features  feature_importances
# 0       age             0.043441
# 1       sex             0.039990
# 2        cp             0.139983
# 3  trestbps             0.053569
# 4      chol             0.056887

# %%
fi_sorted = feature_importances_df.sort_values('feature_importances', ascending=False)

# %%
sns.set_color_codes("muted")
sns.barplot(x="feature_importances", y="features", data=fi_sorted,
            label="importance", color="b")

# %% [markdown]
# **IRIS//////////////**
#
# **> Блок с отступами**
#
# **> Блок с отступами**
#
# **> Блок с отступами**
#
# **//////////////////////**

# %%
df_train = pd.read_csv('https://stepik.org/media/attachments/course/4852/train_iris.csv', index_col=0)
df_test = pd.read_csv('https://stepik.org/media/attachments/course/4852/test_iris.csv', index_col=0)
X_iris_train = df_train.drop(['species'], axis=1)
X_iris_test = df_test.drop(['species'], axis=1)
max_depth_values = range(1,100)

# %%
X_iris_train.head()
# Out:
#      sepal length  sepal width  petal length  petal width
# 130           7.4          2.8           6.1          1.9
# 7             5.0          3.4           1.5          0.2
# 11            4.8          3.4           1.6          0.2
# 142           5.8          2.7           5.1          1.9
# 109           7.2          3.6           6.1          2.5

# %%
rs = np.random.seed(0)
clf_iris = tree.DecisionTreeClassifier(criterion='entropy')

# %%
y_iris_test = df_test.species
y_iris_train = df_train.species
scores_data = pd.DataFrame()

# %%
for max_depth in max_depth_values:
  clf_iris = tree.DecisionTreeClassifier(criterion='entropy', max_depth=max_depth, random_state=rs)
  clf_iris.fit(X_iris_train, y_iris_train)
  train_score = clf_iris.score(X_iris_train, y_iris_train)
  test_score = clf_iris.score(X_iris_test, y_iris_test)

  #mean_cross_val_score = cross_val_score(clf_iris, X_iris_train, y_iris_train, cv=5).mean()
  temp_score = pd.DataFrame({'max_depth':[max_depth], 'train_score' : [train_score], 'test_score':[test_score]})#, 'cross_val_score': [mean_cross_val_score]})
  scores_data = scores_data.append(temp_score)

# %%
scores_data.head()
# Out:
#    max_depth  train_score  test_score
# 0          1         0.70        0.60
# 0          2         0.97        0.94
# 0          3         0.99        0.94
# 0          4         1.00        0.92
# 0          5         1.00        0.92

# %%
scores_data_long = pd.melt(scores_data, id_vars=['max_depth'], value_vars=['train_score', 'test_score'],#, 'cross_val_score'],
                           var_name='set_type', value_name='score')

# %%
scores_data_long.head()
# Out:
#    max_depth     set_type  score
# 0          1  train_score   0.70
# 1          2  train_score   0.97
# 2          3  train_score   0.99
# 3          4  train_score   1.00
# 4          5  train_score   1.00

# %%
sns.lineplot(x="max_depth", y="score", hue="set_type", data=scores_data_long)

# %%
df_dc = pd.read_csv('https://stepik.org/media/attachments/course/4852/dogs_n_cats.csv')

# %%
df_dc.head()
# Out:
#    Длина  Высота  Шерстист  Гавкает  Лазает по деревьям      Вид
# 0     15    18.0         1        1                   0  собачка
# 1     20    24.0         1        0                   0  собачка
# 2     34    40.8         1        1                   0  собачка
# 3     26    31.2         1        1                   0  собачка
# 4     16    19.2         1        1                   0  собачка

# %%
X = df_dc.drop(['Вид'], axis=1)
y = df_dc['Вид']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state = 42)

# %%
clf = tree.DecisionTreeClassifier(criterion='entropy')

# %%
clf.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy')

# %%
clf.score(X_test, y_test)
# Out:
# 1.0

# %%
df_tst = pd.read_json('http://pastie.org/p/56uKAiZyoKvLnzvB52iuT9/raw')
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-81-29b8a55d2a99> in <module>()
# ----> 1 df_tst = pd.read_json('http://pastie.org/p/56uKAiZyoKvLnzvB52iuT9/raw')
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     197                 else:
#     198                     kwargs[new_arg_name] = new_arg_value
# --> 199             return func(*args, **kwargs)
#     200
#     201         return cast(F, wrapper)
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     294                 )
#     295                 warnings.warn(msg, FutureWarning, stacklevel=stacklevel)
# --> 296             return func(*args, **kwargs)
#     297
#     298         return wrapper
#
# ...

# %%
df_tst.head()

# %%
result = clf.predict(df_tst)

# %%
pd.Series(result)[result=='собачка'].count()

# %%
 prec =15/30

# %%
rec = 15/45

# %%
2 * (prec * rec)/(prec + rec)

# %%
data = pd.read_csv('https://stepik.org/media/attachments/course/4852/train_data_tree.csv', )

# %%
data.head()

# %%
data_X = data[['sex','exang']]

# %%
data_y = data.num

# %%
clf_data = tree.DecisionTreeClassifier(criterion='entropy')

# %%
clf_data.fit(data_X, data_y)

# %%
tree.plot_tree(clf_data, filled=True)

# %%
0.996 - (157 * 0.903 + 81 * 0.826)/238

# %%
training_mush = pd.read_csv('https://stepik.org/media/attachments/course/4852/training_mush.csv')

# %%
rf_mush = RandomForestClassifier(random_state=0)

# %%
parameters = {'n_estimators':[10,20,30,40,50], 'max_depth':[1,3,5,7,9,11,12], 'min_samples_leaf':range(1,7), 'min_samples_split':[2,4,6,8,9]}

# %%
grid_search_cv_clf_mush = GridSearchCV(rf_mush, parameters, cv = 3, n_jobs=-1)

# %%
training_mush.head()
# Out:
#    cap-shape  cap-surface  cap-color  ...  population  habitat  class
# 0          2            0          3  ...           5        0      0
# 1          2            0          4  ...           4        0      1
# 2          2            0          3  ...           5        1      1
# 3          0            0          3  ...           3        1      0
# 4          2            3          3  ...           5        0      0
#
# [5 rows x 23 columns]

# %%
X = training_mush.drop(columns={'class'}, axis=1)

# %%
X.head()
# Out:
#    cap-shape  cap-surface  cap-color  ...  spore-print-color  population  habitat
# 0          2            0          3  ...                  3           5        0
# 1          2            0          4  ...                  7           4        0
# 2          2            0          3  ...                  1           5        1
# 3          0            0          3  ...                  7           3        1
# 4          2            3          3  ...                  2           5        0
#
# [5 rows x 22 columns]

# %%
y = training_mush['class']

# %%
y.head()
# Out:
# 0    0
# 1    1
# 2    1
# 3    0
# 4    0
# Name: class, dtype: int64

# %%
grid_search_cv_clf_mush.fit(X,y)
# Out:
# GridSearchCV(cv=3, estimator=RandomForestClassifier(random_state=0), n_jobs=-1,
#              param_grid={'max_depth': [1, 3, 5, 7, 9, 11, 12],
#                          'min_samples_leaf': range(1, 7),
#                          'min_samples_split': [2, 4, 6, 8, 9],
#                          'n_estimators': [10, 20, 30, 40, 50]})

# %%
grid_search_cv_clf_mush.best_estimator_
# Out:
# RandomForestClassifier(max_depth=9, n_estimators=10, random_state=0)

# %%
grid_search_cv_clf_mush.best_params_
# Out:
# {'max_depth': 9,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'n_estimators': 10}

# %%
mush_importances = rf_mush.feature_importances_

# %%
rf_mush.fit(X,y)
# Out:
# RandomForestClassifier(random_state=0)

# %%
feature_importances_df_mush = pd.DataFrame({'features':list(X),
                                       'mush_importances':mush_importances})

# %%
feature_importances_df_mush.sort_values('mush_importances', ascending=False)
# Out:
#                     features  mush_importances
# 4                       odor          0.135206
# 7                  gill-size          0.113330
# 19         spore-print-color          0.100540
# 8                 gill-color          0.081375
# 20                population          0.073592
# 18                 ring-type          0.072367
# 3                    bruises          0.071691
# 10                stalk-root          0.063895
# 11  stalk-surface-above-ring          0.059125
# 6               gill-spacing          0.049065
# 12  stalk-surface-below-ring          0.048822
# 21                   habitat          0.033653
# 9                stalk-shape          0.021000
# 14    stalk-color-below-ring          0.017870
# 2                  cap-color          0.014665
# 13    stalk-color-above-ring          0.012498
# 17               ring-number          0.010784
# 1                cap-surface          0.009454
# 0                  cap-shape          0.005047
# ...

# %%
test_mush = pd.read_csv('https://stepik.org/media/attachments/course/4852/testing_mush.csv')

# %%
test_mush.head()
# Out:
#    cap-shape  cap-surface  cap-color  ...  spore-print-color  population  habitat
# 0          0            3          8  ...                  2           3        3
# 1          5            3          4  ...                  3           5        0
# 2          3            3          4  ...                  7           4        4
# 3          3            2          2  ...                  7           4        0
# 4          3            2          2  ...                  7           4        4
#
# [5 rows x 22 columns]

# %%
test_out = grid_search_cv_clf_mush.predict(test_mush)

# %%
test_out
# Out:
# array([0, 0, 1, ..., 1, 0, 1])

# %%
sum(test_out)
# Out:
# 976

# %%
url = "https://stepik.org/media/attachments/course/4852/testing_y_mush.csv.zip"
r = requests.get(url)
z = zipfile.ZipFile(io.BytesIO(r.content))
txtfiles = z.namelist()
y_real = pd.read_csv(z.open(txtfiles[0], "r", pwd='Cool!Move_forward!'.encode('cp850', 'replace')))

# %%
y_real.head()
# Out:
#    class
# 0      0
# 1      0
# 2      1
# 3      1
# 4      1

# %%
conf_mush = confusion_matrix(y_real,test_out)

# %%
sns.heatmap(conf_mush, annot=True, cmap="Blues")

# %%
invasion = pd.read_csv('https://stepik.org/media/attachments/course/4852/invasion.csv')

# %%
invasion.head()
# Out:
#        class  g_reflection  ...  time_of_observance     volume
# 0  transport      2.190672  ...              158221  44.932446
# 1  transport      3.453276  ...              385972  41.568300
# 2  transport      2.432994  ...              446482  40.123467
# 3    fighter      6.083763  ...              210125  11.384865
# 4    fighter     12.876769  ...               23109  11.328806
#
# [5 rows x 7 columns]

# %%
rf_invasion = RandomForestClassifier()

# %%
params_invasion =  {'n_estimators':range(1,20,1), 'max_depth':range(1,13,2), 'min_samples_leaf':range(1,8), 'min_samples_split':range(2,10,2)}

# %%
X = invasion.drop(columns=['class'])

# %%
X.head()
# Out:
#    g_reflection  i_reflection  ...  time_of_observance     volume
# 0      2.190672      6.716633  ...              158221  44.932446
# 1      3.453276      8.995909  ...              385972  41.568300
# 2      2.432994      6.938691  ...              446482  40.123467
# 3      6.083763      3.019459  ...              210125  11.384865
# 4     12.876769      2.452950  ...               23109  11.328806
#
# [5 rows x 6 columns]

# %%
y = invasion['class']

# %%
gridSearchCvRfInv = GridSearchCV(rf_invasion, params_invasion, cv=3)

# %%
gridSearchCvRfInv.fit(X,y)
# Out:
# GridSearchCV(cv=3, estimator=RandomForestClassifier(),
#              param_grid={'max_depth': range(1, 13, 2),
#                          'min_samples_leaf': range(1, 8),
#                          'min_samples_split': range(2, 10, 2),
#                          'n_estimators': range(1, 20)})

# %%
bestInvClf = gridSearchCvRfInv.best_estimator_

# %%
operativeData = pd.read_csv('https://stepik.org/media/attachments/course/4852/operative_information.csv')

# %%
bestInvClf.fit(X,y)
# Out:
# RandomForestClassifier(max_depth=3, n_estimators=2)

# %%
out_pred = bestInvClf.predict(operativeData)

# %%
pd.Series(out_pred).value_counts()
# Out:
# fighter      675
# transport    595
# cruiser      230
# dtype: int64

# %%
rf_invasion.fit(X,y)
# Out:
# RandomForestClassifier()

# %%
inv_features = rf_invasion.feature_importances_

# %%
inv_features_df = pd.DataFrame({'features':list(X),
                                       'inv_features':inv_features})

# %%
inv_features_df.sort_values('inv_features', ascending=False)
# Out:
#              features  inv_features
# 5              volume      0.319534
# 0        g_reflection      0.241259
# 3          brightness      0.222114
# 2               speed      0.139568
# 1        i_reflection      0.076737
# 4  time_of_observance      0.000786

# %%
spaceData = pd.read_csv('https://stepik.org/media/attachments/course/4852/space_can_be_a_dangerous_place.csv')

# %%
spaceData.corr()
# Out:
#                                   r  ...  dangerous
# r                          1.000000  ...   0.005788
# phi                        0.001023  ...   0.003035
# peradventure_index         1.000000  ...   0.005788
# dustiness                 -0.003336  ...  -0.000499
# black_hole_is_near         0.002337  ...   0.052968
# buggers_were_noticed       0.001797  ...   0.344469
# nearby_system_has_planemo  0.000326  ...   0.299508
# dangerous                  0.005788  ...   1.000000
#
# [8 rows x 8 columns]

# %%
sns.heatmap(spaceData.corr(), annot=True)

# %%
df = pd.DataFrame(range(10000000))

# %time df.apply(np.mean)

# %time df.apply('mean')

# %time df.describe().loc['mean']

# %time df.mean(axis=0)
# Out:
# CPU times: user 22.8 ms, sys: 715 µs, total: 23.5 ms
# Wall time: 30 ms
# CPU times: user 19.4 ms, sys: 0 ns, total: 19.4 ms
# Wall time: 19.4 ms
# CPU times: user 243 ms, sys: 126 ms, total: 369 ms
# Wall time: 378 ms
# CPU times: user 22.8 ms, sys: 0 ns, total: 22.8 ms
# Wall time: 19.9 ms
# 0    4999999.5
# dtype: float64

# %%
xM = (1 + 5 + 2 + 7 + 1 + 9 + 3 + 8 + 5 + 9)/10
xM
# Out:
# 5.0

# %%
D = ((1-xM)**2+(5-xM)**2+ (2-xM)**2 + (7-xM)**2 + (1-xM)**2 + (9-xM)**2 + (3-xM)**2 + (8-xM)**2 + (5-xM)**2 + (9-xM)**2)/9
D
# Out:
# 10.0

# %%
sd = math.sqrt(D)
sd
# Out:
# 3.1622776601683795
